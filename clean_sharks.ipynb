# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %%
file_to_load = "shark_attacks.csv"
df = pd.read_csv(file_to_load)
df.head()
# Out:
#   Case Number       Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# ...

# %%
#clean_df = df[df["Date"]!=" "]
#print(clean_df['Date'])

df_1975 = df[df["Year"]>=1975]
df_1975
# Out:
#        Case Number       Date    Year        Type       Country  \
# 0       2018.06.25  25-Jun-18  2018.0     Boating           USA
# 1       2018.06.18  18-Jun-18  2018.0  Unprovoked           USA
# 2       2018.06.09   9-Jun-18  2018.0     Invalid           USA
# 3       2018.06.08   8-Jun-18  2018.0  Unprovoked     AUSTRALIA
# 4       2018.06.04   4-Jun-18  2018.0    Provoked        MEXICO
# ...            ...        ...     ...         ...           ...
# 3242    1975.02.07   7-Feb-75  1975.0  Unprovoked     AUSTRALIA
# 3243    1975.02.01   1-Feb-75  1975.0    Provoked  SOUTH AFRICA
# 3244    1975.01.19  19-Jan-75  1975.0  Unprovoked     AUSTRALIA
# 3245  1975.00.00.b       1975  1975.0  Unprovoked       BERMUDA
# 3246  1975.00.00.a       1975  1975.0  Unprovoked       REUNION
#
#                        Area                        Location      Activity  \
# 0                California     Oceanside, San Diego County      Paddling
# ...

# %%
df_1975['Attack Date'] = df_1975["Case Number"].str.contains("00.00")==False
df_1975_clean = df_1975[df_1975['Attack Date']==True]
df_1975_clean['Attack Date'] = df_1975_clean['Case Number'].str[:10]
df_1975_clean
# Out:
# <ipython-input-32-41286ecdd072>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1975['Attack Date'] = df_1975["Case Number"].str.contains("00.00")==False
# <ipython-input-32-41286ecdd072>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1975_clean['Attack Date'] = df_1975_clean['Case Number'].str[:10]
#      Case Number       Date    Year        Type       Country  \
# 0     2018.06.25  25-Jun-18  2018.0     Boating           USA
# ...

# %%
df_1975_clean['Attack Date'] = df_1975_clean['Attack Date'].str.replace('.','-')
df_1975_clean
# Out:
# <ipython-input-33-933bf62050c2>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_1975_clean['Attack Date'] = df_1975_clean['Attack Date'].str.replace('.','-')
# <ipython-input-33-933bf62050c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1975_clean['Attack Date'] = df_1975_clean['Attack Date'].str.replace('.','-')
#      Case Number       Date    Year        Type       Country  \
# 0     2018.06.25  25-Jun-18  2018.0     Boating           USA
# 1     2018.06.18  18-Jun-18  2018.0  Unprovoked           USA
# 2     2018.06.09   9-Jun-18  2018.0     Invalid           USA
# ...

# %%
df_1975['Attack Date'] = pd.to_datetime(df_1975['Attack Date'], errors='coerce')
df_1975 = df_1975.dropna(subset=['Attack Date'])
#df_1975['Attack Date'] = df_1975['Attack Date'].drop(df.loc[(df.index.month==12)])

df_1975
# Out:
# <ipython-input-79-c9369b412a3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1975['Attack Date'] = pd.to_datetime(df_1975['Attack Date'], errors='coerce')
#      Case Number       Date    Year        Type       Country  \
# 0     2018.06.25  25-Jun-18  2018.0     Boating           USA
# 1     2018.06.18  18-Jun-18  2018.0  Unprovoked           USA
# 2     2018.06.09   9-Jun-18  2018.0     Invalid           USA
# 3     2018.06.08   8-Jun-18  2018.0  Unprovoked     AUSTRALIA
# 4     2018.06.04   4-Jun-18  2018.0    Provoked        MEXICO
# ...          ...        ...     ...         ...           ...
# 3240  1975.02.10  10-Feb-75  1975.0  Unprovoked     AUSTRALIA
# 3241  1975.02.09   9-Feb-75  1975.0  Unprovoked     AUSTRALIA
# ...

# %%
df['Attack Date'] = pd.to_datetime(str(df['Attack Date']), format='%Y%m%d')
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     455             try:
# --> 456                 values, tz = conversion.datetime_to_datetime64(arg)
#     457                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8434fd3ed334> in <module>
# ----> 1 df['Attack Date'] = pd.to_datetime(str(df['Attack Date']), format='%Y%m%d')
#       2 df.head()
#
# ...
